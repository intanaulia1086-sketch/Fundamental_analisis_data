# %% [markdown]
# # Proyek Analisis Data: E-commerce-Public-Dataset
# - **Nama:** Intan Aulia Agustina
# - **Email:** intanaulia1086@gmail.com
# - **ID Dicoding:** intan_aulia_agustina__d80w

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Apa kategori produk yang paling banyak terjual (berdasarkan jumlah pesanan) selama tahun 2017?
# - **Pertanyaan 2:** Apa jenis metode pembayaran yang paling sering digunakan untuk transaksi di tahun 2017?
#
# **Q1 [SMART Method]**
# *   S (Specific): Fokus pada volume penjualan per kategori produk.
# *   M (Measurable): Bisa dihitung dari jumlah baris atau ID pesanan.
# *   A (Action-oriented): Hasilnya membantu menentukan fokus stok barang.
# *   R (Relevant): Penting untuk mengetahui minat pasar.
# *   T (Time-bound): Dibatasi pada tahun 2017.
#
# **Q2 [SMART Method]**
# *   S (Specific): Fokus pada preferensi cara bayar pelanggan.
# *   M (Measurable): Bisa dihitung dari frekuensi setiap jenis pembayaran.
# *   A (Action-oriented): Membantu tim keuangan/IT mengoptimalkan gerbang pembayaran tersebut.
# *   R (Relevant): Penting untuk kemudahan transaksi pelanggan.
# *   T (Time-bound): Dibatasi pada 2017.

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
file_path = '/content/drive/MyDrive/E-Commerce Public Dataset/'

df_customers = pd.read_csv(file_path + 'customers_dataset.csv')
df_geolocation = pd.read_csv(file_path + 'geolocation_dataset.csv')
df_order_items = pd.read_csv(file_path + 'order_items_dataset.csv')
df_order_payments = pd.read_csv(file_path + 'order_payments_dataset.csv')
df_order_reviews = pd.read_csv(file_path + 'order_reviews_dataset.csv')
df_orders = pd.read_csv(file_path + 'orders_dataset.csv')
df_products = pd.read_csv(file_path + 'products_dataset.csv')
df_sellers = pd.read_csv(file_path + 'sellers_dataset.csv')
df_product_category_name_translation = pd.read_csv(file_path + 'product_category_name_translation.csv')

print('data berhasil dimuat!')
# Out:
# data berhasil dimuat!

# %% [markdown]
# **Insight:** (Opsional)
# - Berdasarkan proses gathering data diatas, 9 data terpisah dari dataset e-commerce yang terdiri dari data customers, geolocation, order item, payment, review, order, products, seller, dan kategori berrhasil dimuat.
# - Data-data tersebut merupakan bagian dari basisdata relasional yang terhubung menggunakan primary key. Proses selanjutnya adalah melakukan assesing data, untuk memastikan data siap digunakan.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying ... problem

# %%
df_orders.info()
print('\n')
print("Jumlah duplikasi df_orders: ", df_orders.duplicated().sum())
print('\n')
df_orders.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
#
#
# Jumlah duplikasi df_orders:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# ...

# %%
df_order_items.info()
print('\n')
print("Jumlah duplikasi df_order_items: ", df_order_items.duplicated().sum())
print('\n')
df_order_items.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
#
#
# Jumlah duplikasi df_order_items:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# ...

# %%
df_order_reviews.info()
print('\n')
print("Jumlah duplikasi df_orders: ", df_orders.duplicated().sum())
print('\n')
df_order_reviews.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
#
#
# Jumlah duplikasi df_orders:  0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
df_products.info()
print('\n')
print("Jumlah duplikasi df_products: ", df_products.duplicated().sum())
print('\n')
df_products.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
#
#
# Jumlah duplikasi df_products:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# ...

# %%
df_order_payments.info()
print('\n')
print('Jumlah duplikasi df_order_payments: ', df_order_payments.duplicated().sum())
print('\n')
df_order_payments.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
#
#
# Jumlah duplikasi df_order_payments:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# ...

# %% [markdown]
# **Steps to Take:**
# - Mengubah kolom waktu menjadi tipe datetime pada tabel orders dan order items.
# - Mengisi kategori yang kosong dengan 'unknown' pada tabel products.
# - Menggabungkan orders, order_items, produk, dan translasi nama kategori untuk menjawab pertanyaan no 1.
# - Mengganungkan tabel orders dan payments untuk menjawab soal no 2.
# - Melakukan filter untuk menampilkan data tahun 2017 dengan status 'delivered'.

# %% [markdown]
# **Insight:** (Opsional)
# - **Tipe Data Tidak Sesuai** : Beberapa kolom tanggal seperti order_purchase_timestamp, order_approved_at, dan delivery date masih bertipe object. Selain itu shipping_limit_date pada df_order_items juga masih bertipe object.
#
# - **Missing Values pada Data Penting** : Kolom product_category_name memiliki data kosong cukup banyak. Ini bisa mempengaruhi analisis berdasarkan kategori produk. Beberapa kolom tanggal pengiriman juga kosong.
#
# - **Data Order Tidak Selalu Lengkap** : Jumlah data di tabel orders, order_items, dan payments berbeda. Artinya tidak semua order punya item atau data pembayaran lengkap. Ini perlu dicek saat join data.
#
# - **Duplikasi Data** : Tidak ditemukan duplikasi pada tabel utama seperti orders, order_items, products, dan payments. Data cukup bersih dari sisi redundansi.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
# Melakukan konversi kolom waktu dan mengubahnya menjadi tipe datetime pada tabel order dan order_items
datetime_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"]
for column in datetime_columns:
    df_orders[column] = pd.to_datetime(df_orders[column])

df_order_items["shipping_limit_date"] = pd.to_datetime(df_order_items["shipping_limit_date"])

# Mengisi kategori yang kosong dengan 'unknown' pada tabel products
df_products["product_category_name"] = df_products["product_category_name"].fillna("unknown")

# Menggabungkan orders, order_items, produk, dan translasi nama kategori untuk menjawab pertanyaan no 1
df_q1 = pd.merge(left=df_order_items, right=df_orders, how="left", left_on="order_id", right_on="order_id")
df_q1 = pd.merge(left=df_q1, right=df_products, how="left", left_on="product_id", right_on="product_id")
df_q1 = pd.merge(left=df_q1, right=df_product_category_name_translation, how="left", left_on="product_category_name", right_on="product_category_name")

# Mengganungkan tabel orders dan payments untuk menjawab soal no 2
df_q2 = pd.merge(left=df_order_payments, right=df_orders, how="left", left_on="order_id", right_on="order_id")

# Melakukan filter untuk menampilkan data tahun 2017 dengan status 'delivered'
# Filter Q1 (Kategori)
main_df_q1 = df_q1[(df_q1["order_purchase_timestamp"].dt.year == 2017) & (df_q1["order_status"] == "delivered")]
# Filter Q2 (Pembayaran)
main_df_q2 = df_q2[(df_q2["order_purchase_timestamp"].dt.year == 2017) & (df_q2["order_status"] == "delivered")]

print("Cleaning Selesai!")
print(f"Jumlah baris data kategori 2017: {main_df_q1.shape[0]}")
print(f"Jumlah baris data pembayaran 2017: {main_df_q2.shape[0]}")
# Out:
# Cleaning Selesai!
# Jumlah baris data kategori 2017: 49556
# Jumlah baris data pembayaran 2017: 45725

# %%
main_df_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49556 entries, 0 to 112648
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       49556 non-null  object
#  1   order_item_id                  49556 non-null  int64
#  2   product_id                     49556 non-null  object
#  3   seller_id                      49556 non-null  object
#  4   shipping_limit_date            49556 non-null  datetime64[ns]
#  5   price                          49556 non-null  float64
#  6   freight_value                  49556 non-null  float64
#  7   customer_id                    49556 non-null  object
#  8   order_status                   49556 non-null  object
#  9   order_purchase_timestamp       49556 non-null  datetime64[ns]
#  10  order_approved_at              49541 non-null  datetime64[ns]
#  11  order_delivered_carrier_date   49554 non-null  datetime64[ns]
# ...

# %%
main_df_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45725 entries, 2 to 103885
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       45725 non-null  object
#  1   payment_sequential             45725 non-null  int64
#  2   payment_type                   45725 non-null  object
#  3   payment_installments           45725 non-null  int64
#  4   payment_value                  45725 non-null  float64
#  5   customer_id                    45725 non-null  object
#  6   order_status                   45725 non-null  object
#  7   order_purchase_timestamp       45725 non-null  datetime64[ns]
#  8   order_approved_at              45711 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   45723 non-null  datetime64[ns]
#  10  order_delivered_customer_date  45723 non-null  datetime64[ns]
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - Kesalahan tipe data pada kolom order_purchase_timestamp, order_approved_at, dan delivery date berhasil diubah menjadi tipe datetime.
# - Missing value yang ada pada Kolom product_category_name diubah menjadi 'unknown' agar tidak menggangu proses analisis.
# - Dilakukan penggabungan tabel orders, order_item, dan product untuk menjawab pertanyaan no 1 (df_q1).
# - Dilakukan penggabungan tabel orders, dan payment untuk menjawab pertanyaan no 2 (df_q2).
# - Dilakukan filtering untuk pesanan yang memiliki status 'delivered' agar analisis dapat berfokus pada pesanan yang sudah diterima.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore [Q1]

# %%
# Mencari distribusi frekuensi kategori produk (Kuantitas)
print("Univariate: Top 10 Kategori Produk Berdasarkan Jumlah Order")
# Menghitung jumlah order_id unik untuk setiap kategori produk
category_sales_df = main_df_q1.groupby(by="product_category_name_english").agg({"order_id": "nunique"}).reset_index()
# Mengurutkan dari yang paling banyak terjual
category_sales_df.rename(columns={"order_id": "order_count"}, inplace=True)
category_sales_df = category_sales_df.sort_values(by="order_count", ascending=False)
display(category_sales_df)
print("\n")

# Statistik deskriptif untuk harga produk
print("Numerikal: Statistik Deskriptif Harga Produk (2017)")
display(main_df_q1['price'].describe())
print("\n")

# Menghubungkan Kategori dengan Total Pendapatan (Revenue)
print("Bivariate: Top 10 Kategori Berdasarkan Total Pendapatan (Revenue)")
display(main_df_q1.groupby("product_category_name_english")["price"].sum().sort_values(ascending=False).head(10))
#print(category_revenue)
print("\n")

# Menghubungkan 3 variabel: Bulan (dari timestamp), product_category_name_english, dan price (sum)
main_df_q1['month'] = main_df_q1['order_purchase_timestamp'].dt.month
multivariate_q1 = main_df_q1.groupby(['month', 'product_category_name_english'])['price'].sum().reset_index()

# Menampilkan 10 data teratas dari hasil analisis 3 variabel tersebut
print("Multivariate Analysis (Kategori, Revenue, dan Bulan)")
display(multivariate_q1.sort_values(by=['month', 'price'], ascending=[True, False]).head(10))
# Out:
# Univariate: Top 10 Kategori Produk Berdasarkan Jumlah Order
#             product_category_name_english  order_count
# 7                          bed_bath_table         4423
# 65                         sports_leisure         3540
# 43                          health_beauty         3305
# 39                        furniture_decor         3111
# 15                  computers_accessories         2546
# ..                                    ...          ...
# 29              fashion_childrens_clothes            4
# 64  small_appliances_home_oven_and_coffee            3
# 3                   arts_and_craftmanship            2
# 61                  security_and_services            2
# 23                    diapers_and_hygiene            1
#
# [71 rows x 2 columns]
# Numerikal: Statistik Deskriptif Harga Produk (2017)
# count    49556.000000
# mean       120.326540
# std        186.102158
# min          1.200000
# 25%         39.900000
# 50%         72.000000
# 75%        132.700000
# ...

# %% [markdown]
# ### Explore [Q2]

# %%
# Menghitung frekuensi penggunaan setiap payment_type
print("Distribusi Penggunaan Metode Pembayaran 2017:")
payment_type_usage_df = main_df_q2.groupby(by="payment_type").agg({"order_id": "nunique"}).reset_index()
payment_type_usage_df.rename(columns={"order_id": "usage_count"}, inplace=True)
display(payment_type_usage_df.sort_values(by="usage_count", ascending=False))
print("\n")

# Menganalisis ringkasan statistik dari total uang yang dibayar per transaksi
print("Numerikal Q2 (Statistik Nilai Pembayaran)")
display(main_df_q2['payment_value'].describe().to_frame())
print("\n")

# Menghubungkan 2 variabel: payment_type dan payment_value (Sum)
print("Bivariate Analysis Q2 (Metode Pembayaran vs Total Nilai)")
payment_revenue = main_df_q2.groupby("payment_type")["payment_value"].sum().sort_values(ascending=False).reset_index()
display(payment_revenue)
print("\n")

# Menghubungkan 3 variabel: Bulan, payment_type, dan payment_value (Sum)
print("Multivariate Analysis Q2 (Metode Pembayaran, Nilai, dan Bulan)")
main_df_q2['month'] = main_df_q2['order_purchase_timestamp'].dt.month
multivariate_q2 = main_df_q2.groupby(['month', 'payment_type'])['payment_value'].sum().reset_index()

# Menampilkan hasil tren bulanan
display(multivariate_q2.sort_values(by=['month', 'payment_value'], ascending=[True, False]))
# Out:
# Distribusi Penggunaan Metode Pembayaran 2017:
#   payment_type  usage_count
# 1  credit_card        33157
# 0       boleto         9142
# 3      voucher         1850
# 2   debit_card          406
# Numerikal Q2 (Statistik Nilai Pembayaran)
#        payment_value
# count   45725.000000
# mean      151.402958
# std       220.320508
# min         0.000000
# 25%        55.700000
# 50%        97.710000
# 75%       168.200000
# max     13664.080000
# Bivariate Analysis Q2 (Metode Pembayaran vs Total Nilai)
#   payment_type  payment_value
# 0  credit_card     5386253.99
# 1       boleto     1330026.39
# 2      voucher      164661.87
# 3   debit_card       41957.99
# Multivariate Analysis Q2 (Metode Pembayaran, Nilai, dan Bulan)
# /tmp/ipykernel_10127/671100490.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - **Kategori Produk Terlaris**: Terdapat 5 kategori produk terlaris selama penjualan di tahun 2017 yang terdiri dari bed_bath_table (4423), sports_leisure (3540), health_beauty (3305), furniture_decor (3111), dan computers_accessories (2546)
# - **Preferensi Konsumen**: Dari 5 kategori tersebuat, dominasi kategori rumah tangga dan lifestyle menunjukkan bahwa konsumen lebih banyak melakukan pembelian untuk meningkatkan kenyamanan hidup dan kebutuhan personal.
# - **Metode Pembayaran Dominan**: Metode pembayaran credit_card menjadi metode pembayaran terbayak selama tahun 2017 dengan total transaksi 33157. Kemudian diikuti oleh boleto, voucher, dan voucher_card.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
#Visualisasi Univariate 10 produk terlaris 2017
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(
    x="order_count",
    y="product_category_name_english",
    data=category_sales_df.head(5),
    palette="viridis"
)
plt.title('Top 10 Kategori Produk Terlaris di Tahun 2017', fontsize=15)
plt.xlabel('Jumlah Pesanan', fontsize=12)
plt.ylabel('Nama Kategori', fontsize=12)
plt.show()

# Visualisasi Numerikal distribusi harga menggunakan Boxplot untuk melihat outlier
plt.figure(figsize=(10, 5))
sns.boxplot(x=main_df_q1['price'], palette='viridis')
plt.title('Numerikal: Distribusi Harga Produk (2017)')
plt.xlabel('Harga (Price)')
plt.show()

# Visualisasi Bivariate Top 10 Kategori berdasarkan Total Pendapatan
plt.figure(figsize=(12, 6))
category_revenue = main_df_q1.groupby("product_category_name_english")["price"].sum().sort_values(ascending=False).head(10)
category_revenue.plot(kind='bar', color='skyblue')
plt.title('Bivariate: Top 10 Kategori Produk berdasarkan Pendapatan (2017)')
plt.ylabel('Total Pendapatan')
plt.xlabel('Kategori Produk')
plt.xticks(rotation=45)
plt.show()

# Visualisasi Multivariate Tren Pendapatan Bulanan untuk Top 5 Kategori
plt.figure(figsize=(14, 7))
top_5_categories = main_df_q1.groupby("product_category_name_english")["price"].sum().sort_values(ascending=False).head(5).index
df_trend_q1 = main_df_q1[main_df_q1['product_category_name_english'].isin(top_5_categories)]
df_trend_q1 = df_trend_q1.groupby(['month', 'product_category_name_english'])['price'].sum().unstack()

df_trend_q1.plot(kind='line', marker='o', ax=plt.gca())
plt.title('Multivariate: Tren Pendapatan Bulanan Top 5 Kategori (2017)')
plt.ylabel('Total Pendapatan')
plt.xlabel('Bulan')
plt.legend(title='Kategori', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_10127/2907160348.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipykernel_10127/2907160348.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=main_df_q1['price'], palette='viridis')

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Visualisasi Univariate persentase penggunaan metode pembayaran (Pie Chart)
plt.figure(figsize=(8, 8))
payment_counts = main_df_q2['payment_type'].value_counts()
plt.pie(payment_counts, labels=payment_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Univariate: Persentase Metode Pembayaran (2017)')
plt.show()

#Visualisasi Numerikal Boxplot: Melihat rentang, median, dan outlier
plt.figure(figsize=(10, 5))
sns.boxplot(x=main_df_q2['payment_value'], palette='viridis')
plt.title('Numerikal: Distribusi Nilai Transaksi (2017)')
plt.xlabel('Payment Value')
plt.show()
# Menampilkan statistik deskriptifnya lagi di bawah grafik sebagai pendukung
print("Statistik Deskriptif Payment Value:")
display(main_df_q2['payment_value'].describe().to_frame().T)

# Visualisasi Bivariate Rata-rata Nilai Transaksi per Metode Pembayaran
plt.figure(figsize=(10, 6))
avg_payment_val = main_df_q2.groupby("payment_type")["payment_value"].mean().sort_values(ascending=False)
sns.barplot(x=avg_payment_val.index, y=avg_payment_val.values, palette='viridis')
plt.title('Bivariate: Rata-rata Nilai Transaksi per Metode Pembayaran')
plt.ylabel('Rata-rata Nilai (Payment Value)')
plt.show()

# Visualisasi Multivariate Tren Penggunaan Metode Pembayaran per Bulan
plt.figure(figsize=(14, 7))
df_trend_q2 = main_df_q2.groupby(['month', 'payment_type'])['payment_value'].sum().unstack()

df_trend_q2.plot(kind='line', marker='s', ax=plt.gca())
plt.title('Multivariate: Tren Total Nilai Transaksi per Metode Pembayaran (2017)')
plt.ylabel('Total Nilai Pembayaran')
plt.xlabel('Bulan')
plt.legend(title='Metode', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_10127/1041565598.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=main_df_q2['payment_value'], palette='viridis')
# Statistik Deskriptif Payment Value:
#                  count        mean         std  min   25%    50%    75%  \
# payment_value  45725.0  151.402958  220.320508  0.0  55.7  97.71  168.2
#
#                     max
# payment_value  13664.08
# /tmp/ipykernel_10127/1041565598.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_payment_val.index, y=avg_payment_val.values, palette='viridis')

# %% [markdown]
# **Insight:** (Opsional)
# - **Pertanyaan 1**:
#    - Berdasarkan hasil visualisai kategori bed_bath_table konsisten menduduki peringkat pertama baik sebagai produk terlaris maupun sebagai penyumbang pendapatan terbesar, inni menunjukkan kategori bed_bath_table masih memiliki peminatan pasar tertinggi di 2017.
#    - Kategori lain seperti health_beauty dan watches_gifts sendiri memiliki volume pesanan yang tinggi sekaligus menyumbang pendapatan yang besar sehingga kedua kategri ini masuk kategori "Star Products" yang harus dipertahankan stok dan promosinya.
#    - Berdasarakn tren pendapatan, terdapat lonjakan pendapatan di bulan-bulan tertentu.
#
# - **Pertanyaan 2**:
#   - Mayoritas konsumen (lebih dari 70%) menggunakan kartu kredit (credit_card) untuk melakukan transaksi. Ini menunjukkan bahwa konsumen lebih menyukai metode pembayaran yang cepat dan fleksibel.
#   - Berdasarakan visualisasi bivariate, pembayaran menggunakna kartu kredit menduduki posisi tertinggi pada rata-rata transaksi (payment_value). Ini menunjukkan konsumen cenderung melakukan pembayaran untuk barang dengan nilai tiggi menggunakan kartu kredit.
#   - Nilai pemmbayaran menggunakan credit_card menunjukkan pertumbuhan yang stabil dari awal hingga akhir 2017. Sebaliknya, pembayaran menggunakan metode lain seperti debit_card sangat rendah penggunaannya.
#
#
# - **Kesimpulan**:
#
# Dari kedua visualisasi dan insight yang didapatkan dari q1 dan q2 tersebut, maka dapat ditarik kesimpulan bahwa pelanggan dominan membeli kebutuhan rumah tangga dan personal dengan melakukan pembayaran menggunakan kartu kredit. Kesimpulan ini kemudian dapat digunakan oleh perusahaan untuk membuat sebuah strategi bisnis baru seperti melakukan peningkatan promosi pada kategori produk terlaris dengan menyediakan lebih banyak program pembayaran berbasis kartu kredit seperti diskon atau cicilan guna meningkatkan penjualan.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
# Menyiapkan data RFM
rfm_data = pd.merge(left=main_df_q1, right=df_customers, how="left", on="customer_id")

# Menentukan tanggal referensi (1 hari setelah transaksi terakhir)
snapshot_date = rfm_data['order_purchase_timestamp'].max() + pd.Timedelta(days=1)

# Membuat dataframe RFM
rfm_df = rfm_data.groupby(by="customer_unique_id", as_index=False).agg({
    "order_purchase_timestamp": lambda x: (snapshot_date - x.max()).days, # Recency
    "order_id": "nunique", # Frequency
    "price": "sum" # Monetary
})

# Rename kolom
rfm_df.columns = ["customer_id", "recency", "frequency", "monetary"]

# Menyiapkan canvas dengan 3 kolom
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 8))

# 1. Berdasarkan Recency (Semakin rendah semakin baik)
sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette="Blues_r", ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel("Customer ID", fontsize=12)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis='x', rotation=45)

# 2. Berdasarkan Frequency (Semakin tinggi semakin baik)
sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette="Greens_r", ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel("Customer ID", fontsize=12)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', rotation=45)

# 3. Berdasarkan Monetary (Semakin tinggi semakin baik)
sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette="Oranges_r", ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel("Customer ID", fontsize=12)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', rotation=45)

plt.suptitle("Best Customer Based on RFM Parameters (Customer ID)", fontsize=25)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# /tmp/ipykernel_10127/156001924.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette="Blues_r", ax=ax[0])
# /tmp/ipykernel_10127/156001924.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette="Greens_r", ax=ax[1])
# /tmp/ipykernel_10127/156001924.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:**
#
# Berdasarkan hasil visualisasi data, kategori produk mendominasi penjualan tahun 2017 adalah bed_bath_table. Kategori ini secara konsisten menduduki peringkat pertama baik sebagai produk terlaris maupun penyumbang pendapatan tertinggi dibandingkan kategori lainnya, hal ini menunjukkan bahwa kebutuhan rumah tangga masih menjadi hal primer yang merupakan komoditas utama dan paling dicari oleh konsumen di platform e-commerce dibandingkan kategori lainnya di periode tersebut.
#
# - **Conclusion pertanyaan 2:**
#
# Hasil analisis menunjukkan bahwa mayoritas konsumen (sekitar lebih dari 70%) lebih memilih melakukan pembayaran menggunakan credit_card (kartu kredit) sebagai pembayaran utama dibandingkan metode pembayaran yang lain. Penggunaan yang sangat dominan ini menunjukkan pelanggan lebih menyukai fleksibelitas dalam sistem pembayaran.

# %% [markdown]
# **Rekomendasi Action Item:**
# - **Optimalisasi Stok Kategori Populer**:
# Perusahaan harus memperhatikan ketersediaan stok untuk kategori produk terlaris terutama kategori produk bed_bath_table agar tidak terjadi kekurangan stok produk, mengingat tingginya permintaan konsumen pada kategori tersebut. Selain itu, tim marketinng juga bisa membuat program kampanye seperti bundling produk di kategori produk terlaris untuk meningkatkan nilai transaksi rata-rata.
#
# - **Kerja Sama Strategis dengan Perbankan**:
# Melihat bahwa pembayaran kartu kredit menjadi pembayaran favorit sepanjang 2017. Perusahaan dapat memperbanyak kerja sama dengan bank penyedia layanan kartu kredit untuk memberikan promo cashback atau cicilan 0%, yang tentunya hal  ini akan meningkatkan minat konsumen untuk melakukan transaksi dengan jumlah yang lebih besar.
#
# - **Strategi Retensi untuk High-Value Customers (RFM Insight)**:
# Berdasarkan hasil analisis RFM, pelanggan yang masuk dalam segmen Monetary dan Frequency tinggi (pelanggan loyal) seperti program loyalitas atau akses ekslusif untuk produk baru. Hal ini penting untuk menjaga agar mereka tetap aktif bertransaksi di masa depan.
#
# - **Edukasi Metode Pembayaran Lain**:
# Untuk mengatasi ketergantungan pada satu metode pembayaran, perusahaan dapat memberikan insentif kecil (seperti diskon ongkir) bagi konsumen yang berkenan menggunakan metode pembayaran lain seperti debit_card atau e-wallet.
